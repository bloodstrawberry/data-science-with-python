# %%
# K-Means
# 최초 시작점은 random
# 하나의 군집에 중심점이 된 항목은 갱신 과정에서 바뀔 수 있다.
# 임의의 중심점이 설정되므로 최종 군집 결과가 다를 수 있다.
# distortion function(데이터 포인트와 중심점 간의 거리 제곱 합)을 줄이는 방향으로 갱신된다.

# 결과가 잘 나오지 않는 경우
# 이상치가 존재하거나, 데이터간 밀도차가 존재하는 경우 
# 데이터가 구형(convex)이 아니거나, 크기, 밀집도, 방향이 다른 경우 
# 이상치에 민감
# 적절하지 않은 초기치, K값

# %% [markdown]
# ![image.png](attachment:image.png)
