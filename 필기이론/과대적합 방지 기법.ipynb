# %% [markdown]
# ![image.png](attachment:image.png)

# %%
드롭아웃은 특정 변수의 특징만을 과도하게 집중하여 학습하는 것을 방지하기 위해 무작위로 신경망 일부를 삭제하는 기법
변수 간 상관관계가 높은 상황에서 상대적으로 예측 성능이 우수한 것은 릿지(Ridge)

# %%
옳지 않은 것

라쏘 기법과 릿지 기법 공식에서 감마( λ )는 초매개변수로 과대적합을 방지하기 위해서 감마를 0으로 가깝게 조절해야 한다. (X)
ㄴ 감마가 0이면 전체 식은 훈련 데이터만 예측하는 식이 되어 과대적합이 유발된다.
ㄴ 감마가 커진다면 전체 손실함수 값을 줄이기 위해 가중치의 합을 감소시켜야 하므로 과대적합 방지 및 정규화가 가능
