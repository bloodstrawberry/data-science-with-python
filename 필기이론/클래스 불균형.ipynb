# %%
# 클래스 불균형 문제의 해결을 통해 성능 향상을 기대할 수 있는 분류 지표는?
# 정밀도, 재현율, F1-Score, ROC-AUC
# 정확도는 부적절.

# %%
# 언더 샘플링
# 랜덤 언더 샘플링
# Tomek Links

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# 임계값 조정
# 임계점(threshold) 조정은 모델이 출력하는 확률값(probability)을 기준으로 최종 클래스 라벨을 정하는 기준점을 조정하는 방법

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 오버 샘플링
# SMOTE 
# ADASYN - SMOTE의 보완, 밀도가 낮은 영역에 표본이 더 만들어지도록 개선
# 랜덤 오버 샘플링

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
