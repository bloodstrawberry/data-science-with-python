# %%
# 다중 선형 회귀 - 다중공선성
# 독립 변수 간의 상관도가 높으면 다중공선성 문제를 가지고 있다고 할 수 있다.
# 분산팽창계수(VIF)를 기준으로 높은 변수를 제거하면서 문제를 완화할 수 있다.
# 다중공선성 문제가 클수록 독립 변수들의 회귀 계수의 변동성이 커지고, 신뢰 구간은 넓어진다.

# %%
# 수정된 결정 계수
# 결정 계수가 종속 변수와 상관 없더라도, 독립 변수가 증가할수록 무조건 커지는 경향을 완화해준다.
# 영향점 : 회귀 계수에 미치는 영향이 큰 데이터 포인트 (이상치와 무관)

# %%
# DFBETAS는 데이터 포인트 하나를 제거했을 대 회귀 계수의 변동량

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# F-통계량

# %% [markdown]
# ![image.png](attachment:image.png)
