# %%
# 머신러닝에서 성능 향상, 과적합 방지, 학습 시간 단축 등을 위해 중요하지 않거나 불필요한 특성(속성)을 제거하는 과정

# 웨퍼(Wrapper)는 머신 러닝 모델을 사용하므로 Filter보다 많은 연산 자원을 필요
# 웨퍼는 변수 간의 상호작용을 고려, 필터는 고려하지 않는다.
# 웨퍼의 All Subset 방법은 연산량이 커서 작은 규모의 데이터에서만 사용
# 웨퍼기반 방법 중 단계적 전진선택법에서, 전진선택 후에 후진 제거시 성능에 개선이 있다면 선택되었던 변수가 제거될 수도 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
