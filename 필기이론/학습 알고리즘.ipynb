# %%
# 최적화 알고리즘
# EM : Expectation-Maximization

# 잠재 변수(Latent Variable)가 확률 모델에서 최대우도추정(Maximum Likelihood Estimation)을 구하는 기법

# 직접적으로 관측되지 않은 데이터(잠재 변수) 때문에 전체 가능도(likelihood)를 직접 극대화하기 어렵기 때문에,
# 관측된 데이터만을 이용해서 기대값을 구하고 반복적으로 파라미터를 갱신하는 방식입니다.

# 가우시안 혼합 모델의 잠재변수에는 혼합 모델의 가우시안 분포들 중에서 각 관측값들이 어느 분포에 생성된 것인지를 나타내는 변수가 있다.
# EM 알고리즘의 기대값에서는 현재 모수로 정의된 잠재 변수의 확률 분포에서 다음 단계 모수에 대한 로그 우도에 대한 기대값을 구한다.
# Metropolis-Hastings 알고리즘에서 제안된 상태의 수용확률을 계산하기 위해 현재까지 수용되었던 상태만 이용한다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
