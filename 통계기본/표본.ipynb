# %%
# 모집단 : 분석하려고 하는 대상 전체 그룹
# 표본 : 모집단에서 선택된 항목

# %%
# 모집단 평균 : mu
# 표본 평균 : x_
# 모집단 평균값에 대한 점추정 : mu_hat (표본 데이터를 기반으로 모집단의 평균을 최대한 예측한 값)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
