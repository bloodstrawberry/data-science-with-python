# %%
# F 검정(F-test)은 두 개 이상의 분산을 비교하여 집단 간의 분산 차이가 유의미한지를 검정하는 통계적 방법입니다.
# 가장 대표적으로는 두 모집단이 같은 분산을 가지는지(등분산성) 또는 집단 간 평균 차이가 유의미한지(분산 분석)를 평가

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
