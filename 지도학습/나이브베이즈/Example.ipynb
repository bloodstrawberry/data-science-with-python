# %%
# 장점
# 연산량이 많이 필요하지 않아 규모가 커도 잘 적용됨.
# 단어 빈도수 기반의 텍스트 분류, 추천 등 동일한 척도의 여러 속성을 지닌 데이터에 강함.
# 발생 빈도가 매우 적은 일부 속성의 성능 저하 현상은 가법 평활화로 완화

# %%
# 단점
# 데이터 간의 복잡한 상관 관계나 패턴은 캡처하지 못함

# %%
# 가법 평활화(Additive Smoothing)
# 클래스에 대한 속성의 조건부 확률이 0이 되는 것을 방지하기 위한 테크닉
# 소수 클래스를 처리하는 것은 아니므로 클래스 불균형 자체를 해결하지는 않는다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 라플라스 평활화 일반화 버전
# #### α를 0부터 증가시키면 평가 성능이 증가하다가, 어느 수준 이상이면 점점 낮아진다.
#
# ![image.png](attachment:image.png)
