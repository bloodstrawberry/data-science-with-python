# %%
# 장점
# 데이터 전처리 필요성이 적음
# 모델에 가정을 두고 있지 않음
# 직관적인 해석이 가능

# %%
# 단점
# 데이터의 작은 변화에도 모델의 결과가 변하기 쉬움

# %%
# 과적합 해결
# 최대 깊이의 크기를 줄인다.
# 리프 노드의 최대 수를 줄인다.
# 리프 노드 생성에 필요한 최소 표본 수를 늘린다.
# 분기(내부 노드)를 생성하기 위한 최소 표본수를 늘린다. (최소 표본 수가 줄어들면 더 많은 내부 노드가 생성되어 복잡도 증가, 과적합 발생)

# %%
# 의사결정나무(Decision Tree)에서 자식 노드를 나누는 기준
# 분할 전과 후의 불순도(impurity) 감소량을 최대화하기

# 엔트로피, 지니 불순도, 카이제곱 통계량, 분산 감소, 게인 비율 등

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 의사결정나무 구성 전략 (Tree Growing Strategies)
# 성능 우선(Best-First) 방식이 레벨 기준(Level-Wise)보다 학습 데이터를 가깝게 맞춰서 과적합이 더 쉽게 발생
# ㄴ 데이터에 가장 잘 맞는 방향으로 트리를 깊게 성장시킴
# 성능 우선 방식이 레벨 기준보다 계산량이 많음.

# 레벨 기준 방식이 성능 우선 보다 비효율적인 분할을 지닐 가능성이 높음
# 레벨 기준 방식이 성능 우선 보다 병렬 처리에 용이

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
