# %%
# 선형 회귀는 특정 피처와 다른 피처의 값들이 강한 선형상관계수를 가지고 있으면 둘 중 하나는 피처로 선택하지 않는다.

# %%
# 선형 모델은 계수의 크기가 커지는 것을 억제하는 규제로 분산과 편향을 제어한다.
# l1 규제 : 라쏘, 가중치에 대한 절대값의 합
# l2 규제 : 릿지, 가중치에 대한 제곱합
# λ가 작으면 패널티가 약해져서 과적합이 발생할 수 있다. 
# → λ를 증가시켜서 회귀 계수의 절대 크기를 억제하여 모델의 분산을 낮춘다.

# 라쏘 회귀 모델이 회귀 계수가 0에 가깝게 되는 경우가 발생한다. (속성 선택법으로 사용 가능)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# GLM (Generalized Linear Model, GLM)
# 선형 회귀 모델을 링크 함수를 통해 출력 변수의 분포를 바꾸어 적용 영역을 확장할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)
