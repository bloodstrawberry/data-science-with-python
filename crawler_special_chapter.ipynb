# %%
import os
import time
import random
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from IPython.display import Audio, display
import numpy as np

cartoon = "My Favorite Idol's Children"
front_url = "https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5"
chap_str = "029.5"

# base_url = "https://fanfox.net/manga/yakusoku_no_neverland/c000/1.html#ipg{}"

print('start')

# 크롬 옵션 (헤드리스)
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_argument("user-agent=Mozilla/5.0")

time.sleep(3)  # JS 로딩 대기

os.makedirs(cartoon, exist_ok=True)

for chapter in range(0, 1):    
    os.makedirs(f"{cartoon}/{chap_str}", exist_ok=True)    
    
    for page in range(1, 200):
        base_url = front_url + "/1.html#ipg" + str(page)
        url = base_url
        
        print(f"\n===== 접속: ipg : {url}") 

        driver = webdriver.Chrome(options=options)
        driver.get(url)

        sleep_time = random.uniform(1, 3)
        time.sleep(sleep_time)

        imgs = driver.find_elements(By.CLASS_NAME, "reader-main-img")

        print("찾은 이미지 개수:", len(imgs))
        if (len(imgs) == 0) and (page > 5) : break
        
        page_str = "img_" + str(page).zfill(3)
        for img in imgs:
            img_url = img.get_attribute("src")
            # img_url = img.get_attribute("data-src")

            if img_url.startswith("//"):
                img_url = "https:" + img_url

            # print("이미지 URL:", img_url)

            # 세션 쿠키 복사
            cookies = driver.get_cookies()
            session = requests.Session()

            for cookie in cookies:
                session.cookies.set(cookie['name'], cookie['value'])

            headers = {
                "User-Agent": "Mozilla/5.0",
                "Referer": url
            }

            img_data = session.get(img_url, headers=headers).content
            filename = img_url.split("/")[-1].split("?")[0]
            
            name, ext = os.path.splitext(filename)

            with open(f"{cartoon}/{chap_str}/{page_str}{ext}", "wb") as f:
                f.write(img_data)

            print("다운로드 완료:", filename)
    
    time.sleep(sleep_time * 5)

driver.quit()
print("완료")
# Out:
# start
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg1
# 찾은 이미지 개수: 1
# 다운로드 완료: t001-1728006590-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg2
# 찾은 이미지 개수: 1
# 다운로드 완료: t002-1728006593-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg3
# 찾은 이미지 개수: 1
# 다운로드 완료: t003-1728006593-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg4
# 찾은 이미지 개수: 1
# 다운로드 완료: t004-1728006594-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg5
# 찾은 이미지 개수: 1
# 다운로드 완료: t005-1728006594-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg6
# 찾은 이미지 개수: 1
# 다운로드 완료: t006-1728006594-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg7
# 찾은 이미지 개수: 1
# 다운로드 완료: t006-1728006593-n.jpg
#
# ===== 접속: ipg : https://fanfox.net/manga/oshi_no_ko_yokoyari_mengo/c029.5/1.html#ipg8
# 찾은 이미지 개수: 0
# 완료

# %%
if True:
    fs = 44100
    duration = 0.5

    t = np.linspace(0, duration, int(fs*duration))
    tone = np.sin(2*np.pi*1000*t)

    sound = np.tile(tone, 10)

    display(Audio(sound, rate=fs, autoplay=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27868\279343306.py in <module>
#       3     duration = 0.5
#       4
# ----> 5     t = np.linspace(0, duration, int(fs*duration))
#       6     tone = np.sin(2*np.pi*1000*t)
#       7
#
# NameError: name 'np' is not defined
