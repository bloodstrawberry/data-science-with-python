# %%
root_folder = r"TEST"

# %%
# 문구 자르기

import cv2
import numpy as np
import os

def crop_single_image(image):
    """
    Crops the image to remove the bottom text block, trims extra white space,
    and adds 2 white lines at the bottom.
    """
    height, width = image.shape[:2]

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Binarize the image (invert so black pixels are 255)
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Calculate the number of black pixels per row
    row_sums = np.sum(binary // 255, axis=1)

    # Threshold for considering a row as having content (adjust if needed)
    content_threshold = 5  # Small number to ignore noise

    # Find rows with content
    content_rows = np.where(row_sums > content_threshold)[0]

    if len(content_rows) == 0:
        # No content, return original
        return image
    else:
        # Find content blocks separated by significant gaps
        min_gap_size = 10  # Adjusted to better separate the bottom text
        
        blocks = []
        start = content_rows[0]
        prev = content_rows[0]
        for row in content_rows[1:]:
            gap = row - prev - 1
            if gap >= min_gap_size:
                blocks.append((start, prev))
                start = row
            prev = row
        blocks.append((start, prev))  # Add the last block
        
        # Assume the main content is all blocks except the last small one (bottom text)
        if len(blocks) > 1:
            last_block_height = blocks[-1][1] - blocks[-1][0] + 1
            if last_block_height < 100:  # Assume bottom text block is smaller than 100 pixels (adjust as needed)
                # Crop to the end of the previous block to remove extra white space
                crop_y = blocks[-2][1] + 1
            else:
                crop_y = height
        else:
            crop_y = height
        
        # Initial crop
        cropped = image[0:crop_y, 0:width]

    # Further trim any remaining white space at top and bottom
    if cropped.size > 0:
        gray_c = cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)
        _, bin_c = cv2.threshold(gray_c, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        row_sums_c = np.sum(bin_c // 255, axis=1)
        content_rows_c = np.where(row_sums_c > content_threshold)[0]
        if len(content_rows_c) > 0:
            top = content_rows_c[0]
            bottom = content_rows_c[-1] + 1
            cropped = cropped[top:bottom, 0:width]

    # Add about 2 white lines (pixels) at the bottom as padding
    if cropped.size > 0:
        padding = 2  # Number of white rows to add; adjust if "lines" means more pixels
        padded_height = cropped.shape[0] + padding
        padded = np.full((padded_height, width, 3), 255, dtype=np.uint8)  # White background
        padded[0:cropped.shape[0], :] = cropped
        cropped = padded

    return cropped

# Set the root folder here (replace with your actual path)
# root_folder = r"My Favorite Idol's Children"  # e.g., '/Users/yourname/images'

# Supported image extensions
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')  # Add more if needed

# Traverse the root folder and all subfolders
for subdir, _, files in os.walk(root_folder):
    print("subdir :", subdir)
    for file in files:
        if file.lower().endswith(image_extensions):
            input_path = os.path.join(subdir, file)
            # print(f"Processing: {input_path}")
            
            # Load the image
            image = cv2.imread(input_path)
            if image is None:
                print(f"Failed to load: {input_path}")
                continue
            
            # Crop the image
            cropped = crop_single_image(image)
            
            # Save with the same name in the same location (overwrites original)
            cv2.imwrite(input_path, cropped)
            # print(f"Saved cropped image: {input_path}")

print("Processing complete.")
# Out:
# subdir : TEST
# subdir : TEST\01
# Processing complete.

# %%
# 개선된 버전 (강철의 연금술사)

import cv2
import numpy as np
import os


def crop_single_image(image):
    """
    Remove bottom white credit/watermark area from manga page.
    """

    height, width = image.shape[:2]

    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 이진화 (흰배경 제거용)
    _, binary = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY_INV)

    # row별 검은 픽셀 비율 계산
    black_ratio = np.sum(binary > 0, axis=1) / width

    threshold = 0.03        # 패널 판단 기준
    min_run = 40            # 연속 row 조건
    run = 0
    cutoff = height

    # 아래에서 위로 검사
    for y in range(height - 1, -1, -1):

        if black_ratio[y] > threshold:
            run += 1
        else:
            run = 0

        if run >= min_run:
            cutoff = y + min_run
            break

    cropped = image[:cutoff, :]

    # 아래 padding 추가
    padding = 2
    padded = np.full((cropped.shape[0] + padding, width, 3), 255, dtype=np.uint8)
    padded[:cropped.shape[0], :] = cropped

    return padded


# root 폴더
# root_folder = r"My Favorite Idol's Children"

# 지원 확장자
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')


for subdir, _, files in os.walk(root_folder):

    print("Processing folder:", subdir)

    for file in files:

        if not file.lower().endswith(image_extensions):
            continue

        input_path = os.path.join(subdir, file)

        image = cv2.imread(input_path)

        if image is None:
            print("Failed:", input_path)
            continue

        cropped = crop_single_image(image)

        cv2.imwrite(input_path, cropped)


print("Processing complete.")
# Out:
# Processing folder: Stop Milky Way
# Processing folder: Stop Milky Way\001
# Processing folder: Stop Milky Way\002
# Processing folder: Stop Milky Way\003
# Processing folder: Stop Milky Way\004
# Processing folder: Stop Milky Way\005
# Processing folder: Stop Milky Way\005.5
# Processing folder: Stop Milky Way\006
# Processing folder: Stop Milky Way\007
# Processing folder: Stop Milky Way\008
# Processing folder: Stop Milky Way\009
# Processing folder: Stop Milky Way\010
# Processing folder: Stop Milky Way\011
# Processing folder: Stop Milky Way\011.5
# Processing folder: Stop Milky Way\012
# Processing folder: Stop Milky Way\013
# Processing folder: Stop Milky Way\014
# Processing folder: Stop Milky Way\015
# Processing folder: Stop Milky Way\016
# Processing folder: Stop Milky Way\017
# Processing folder: Stop Milky Way\017.5
# Processing folder: Stop Milky Way\018
# Processing folder: Stop Milky Way\019
# Processing folder: Stop Milky Way\020
# Processing folder: Stop Milky Way\021
# Processing folder: Stop Milky Way\022
# Processing folder: Stop Milky Way\023
# Processing folder: Stop Milky Way\024
# Processing folder: Stop Milky Way\024.5
# Processing folder: Stop Milky Way\025
# Processing folder: Stop Milky Way\026
# Processing folder: Stop Milky Way\027
# Processing folder: Stop Milky Way\028
# Processing folder: Stop Milky Way\029
# Processing folder: Stop Milky Way\030
# Processing folder: Stop Milky Way\031
# Processing folder: Stop Milky Way\031.5
# Processing folder: Stop Milky Way\032
# Processing folder: Stop Milky Way\033
# Processing folder: Stop Milky Way\034
# Processing folder: Stop Milky Way\035
# Processing folder: Stop Milky Way\036
# Processing folder: Stop Milky Way\037
# Processing folder: Stop Milky Way\038
# Processing folder: Stop Milky Way\039
# Processing folder: Stop Milky Way\040
# Processing folder: Stop Milky Way\041
# Processing folder: Stop Milky Way\042
# Processing folder: Stop Milky Way\043
# Processing folder: Stop Milky Way\044
# Processing folder: Stop Milky Way\045
# Processing folder: Stop Milky Way\046
# Processing folder: Stop Milky Way\047
# Processing folder: Stop Milky Way\048
# Processing folder: Stop Milky Way\049
# Processing folder: Stop Milky Way\050
# Processing folder: Stop Milky Way\051
# Processing folder: Stop Milky Way\052
# Processing folder: Stop Milky Way\053
# Processing folder: Stop Milky Way\054
# Processing folder: Stop Milky Way\055
# Processing folder: Stop Milky Way\056
# Processing folder: Stop Milky Way\057
# Processing folder: Stop Milky Way\058
# Processing folder: Stop Milky Way\059
# Processing folder: Stop Milky Way\059.5
# Processing folder: Stop Milky Way\059.6
# Processing folder: Stop Milky Way\060
# Processing folder: Stop Milky Way\061
# Processing folder: Stop Milky Way\062
# Processing folder: Stop Milky Way\063
# Processing folder: Stop Milky Way\064
# Processing folder: Stop Milky Way\065
# Processing folder: Stop Milky Way\066
# Processing complete.

# %%
# 마지막 이미지 자르기

import os

def delete_last_file_in_subfolders(root_folder):
    # root 폴더 존재 확인
    if not os.path.exists(root_folder):
        print("❌ root 폴더가 존재하지 않습니다.")
        return

    # root 폴더 안의 모든 항목 탐색
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)

        # 폴더인지 확인
        if not os.path.isdir(folder_path):
            continue

        # 해당 폴더 안의 파일 리스트 (파일만)
        files = [
            f for f in os.listdir(folder_path)
            if os.path.isfile(os.path.join(folder_path, f))
        ]

        if len(files) == 0:
            print(f"📂 {folder_name} → 파일 없음")
            continue

        # 파일명 기준 정렬
        files.sort()

        # 마지막 파일
        last_file = files[-1]
        last_file_path = os.path.join(folder_path, last_file)

        try:
            os.remove(last_file_path)
            print(f"🗑 삭제 완료: {last_file_path}")
        except Exception as e:
            print(f"❌ 삭제 실패: {last_file_path} / 오류: {e}")

# ===========================
# 여기 root 폴더 경로 입력
# ===========================
# root_folder = r"My Favorite Idol's Children"

delete_last_file_in_subfolders(root_folder)
# Out:
# 🗑 삭제 완료: Stop Milky Way\001\img_043.jpg
# 🗑 삭제 완료: Stop Milky Way\002\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\003\img_030.jpg
# 🗑 삭제 완료: Stop Milky Way\004\img_036.jpg
# 🗑 삭제 완료: Stop Milky Way\005\img_030.jpg
# 🗑 삭제 완료: Stop Milky Way\005.5\img_011.jpg
# 🗑 삭제 완료: Stop Milky Way\006\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\007\img_023.jpg
# 🗑 삭제 완료: Stop Milky Way\008\img_025.jpg
# 🗑 삭제 완료: Stop Milky Way\009\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\010\img_029.jpg
# 🗑 삭제 완료: Stop Milky Way\011\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\011.5\img_020.jpg
# 🗑 삭제 완료: Stop Milky Way\012\img_022.jpg
# 🗑 삭제 완료: Stop Milky Way\013\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\014\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\015\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\016\img_032.jpg
# 🗑 삭제 완료: Stop Milky Way\017\img_032.jpg
# 🗑 삭제 완료: Stop Milky Way\017.5\img_018.jpg
# 🗑 삭제 완료: Stop Milky Way\018\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\019\img_032.jpg
# 🗑 삭제 완료: Stop Milky Way\020\img_032.jpg
# 🗑 삭제 완료: Stop Milky Way\021\img_019.jpg
# 🗑 삭제 완료: Stop Milky Way\022\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\023\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\024\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\024.5\img_009.jpg
# 🗑 삭제 완료: Stop Milky Way\025\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\026\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\027\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\028\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\029\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\030\img_026.jpg
# 🗑 삭제 완료: Stop Milky Way\031\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\031.5\img_008.jpg
# 🗑 삭제 완료: Stop Milky Way\032\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\033\img_029.jpg
# 🗑 삭제 완료: Stop Milky Way\034\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\035\img_030.jpg
# 🗑 삭제 완료: Stop Milky Way\036\img_029.jpg
# 🗑 삭제 완료: Stop Milky Way\037\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\038\img_030.jpg
# 🗑 삭제 완료: Stop Milky Way\039\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\040\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\041\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\042\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\043\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\044\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\045\img_033.jpg
# 🗑 삭제 완료: Stop Milky Way\046\img_032.jpg
# 🗑 삭제 완료: Stop Milky Way\047\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\048\img_026.jpg
# 🗑 삭제 완료: Stop Milky Way\049\img_026.jpg
# 🗑 삭제 완료: Stop Milky Way\050\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\051\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\052\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\053\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\054\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\055\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\056\img_027.jpg
# 🗑 삭제 완료: Stop Milky Way\057\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\058\img_028.jpg
# 🗑 삭제 완료: Stop Milky Way\059\img_031.jpg
# 🗑 삭제 완료: Stop Milky Way\059.5\img_037.jpg
# 🗑 삭제 완료: Stop Milky Way\059.6\img_215.jpg
# 🗑 삭제 완료: Stop Milky Way\060\img_035.jpg
# 🗑 삭제 완료: Stop Milky Way\061\img_040.jpg
# 🗑 삭제 완료: Stop Milky Way\062\img_041.jpg
# 🗑 삭제 완료: Stop Milky Way\063\img_035.jpg
# 🗑 삭제 완료: Stop Milky Way\064\img_034.jpg
# 🗑 삭제 완료: Stop Milky Way\065\img_035.jpg
# 🗑 삭제 완료: Stop Milky Way\066\img_035.jpg
