# %%
import numpy as np

np.random.seed(1234)

X = np.random.rand(100, 1) * 10
y = 3 * X.squeeze() + 4 + np.random.normal(0, 2, 100)  # y = 3x + 4 + noise

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

y_pred
# Out:
# array([ 9.85324563, 22.66986389, 17.18170803, 27.52904276, 27.36882285,
#        12.26641202, 12.38165282, 28.02057475, 32.67191339, 30.22500613,
#        14.80314933, 19.06488047, 24.4960887 , 25.3663989 , 15.17323567,
#        20.85678281, 19.12703159,  4.56243461, 27.15602521, 30.42468827,
#        15.01355169, 22.47006159,  6.39635756, 15.13076808, 31.92780328,
#        23.54107539, 15.97546464, 27.62939821, 13.58333336, 21.06223677,
#        30.022446  , 17.13544338, 28.02877404,  8.43187462, 25.11514838,
#        25.1246833 , 10.66502427, 31.68157067, 17.31306277, 31.21867063,
#         5.93285182,  9.6379721 ,  5.5621565 , 24.24064318, 21.85179478,
#        20.0267471 ,  5.44216616, 20.86383403, 13.96529126, 19.12356893,
#         7.48318004, 22.22591258, 20.99812204,  4.35394695, 22.5309474 ,
#        31.30221965, 27.68279686, 33.68221039, 32.69163017, 27.72565895,
#        12.64319169, 22.75344288, 18.38321563,  9.97694211, 15.53240448,
#         5.75617879, 17.59606086, 33.3822737 ,  7.84180372,  7.70602032,
#        26.13496945, 21.63387869, 18.19089427,  7.34127399, 10.97537092,
#        30.94034237, 16.55740474, 20.10239559,  4.33741098, 13.10130178,
#        17.1568669 , 22.37340827, 31.48304945, 22.77784937, 25.16683861,
#         8.61245744, 26.35941029, 28.88778112, 23.01564726, 17.19903566,
#         8.69398633, 21.07149266, 19.87536422, 32.4721707 , 18.45064541,
#        19.11144643, 20.13295057, 28.53640403,  5.85267648, 24.07814847])

# %%
residuals = y - y_pred
residuals
# Out:
# array([ 1.42707535,  1.96323893,  0.49179584,  2.81568714,  0.19013602,
#        -0.88856303, -2.14342629, -1.13384585,  1.70545508, -0.11092119,
#        -0.75816326,  1.02154959, -2.13017821, -1.0091007 ,  0.51669769,
#         1.11217016,  0.97264689,  0.42121024,  0.99734967,  2.78151047,
#        -1.62918274, -0.94421157,  2.3142284 , -2.62826445,  1.81735079,
#        -3.42116174, -0.96091752,  1.53083369, -0.48611543, -0.38362801,
#         1.4126877 , -3.68723865,  0.1297985 ,  0.67081853, -0.48418335,
#        -1.22265735, -1.46702909,  0.9369734 , -3.45486565,  0.84822934,
#        -1.09722314, -0.70739218,  1.24670844,  1.36304447,  0.46606061,
#         0.27501105,  1.48981018,  3.76622731,  1.20402763, -1.9586216 ,
#        -4.2968818 ,  3.85039214, -3.49048049,  2.26974232,  1.5871747 ,
#        -0.69815463,  1.43805158, -1.62045895,  2.42604759, -1.0154071 ,
#         1.31615257,  1.96243442, -0.28385857,  4.62485051,  0.92940493,
#         1.4532215 , -0.99465039, -0.03552289,  2.59207181, -1.73426083,
#        -4.22651827, -0.68177457, -1.81535695,  0.54092639,  0.97475369,
#        -1.42904727, -0.69520637, -1.85924343, -1.87049208,  0.36992037,
#         1.20747991,  0.36405034,  1.9678495 ,  1.9705259 , -0.13212828,
#        -1.21865181, -1.85381324, -2.43571447,  0.27549236, -0.49577719,
#         4.13058069,  0.22534267, -2.84749937,  2.91666412, -4.33558013,
#        -2.72972455,  0.70052434,  0.01015376,  2.40558282, -2.89462939])

# %%
from scipy.stats import shapiro

stat, p_value = shapiro(residuals)

stat, p_value
# Out:
# (0.9902440905570984, 0.6843351721763611)

# %%
if p_value > 0.05:
    print("✔️ 잔차는 정규성을 따른다고 볼 수 있음 (귀무가설 채택)")
else:
    print("❌ 잔차는 정규성을 따른다고 보기 어려움 (귀무가설 기각)")
# Out:
# ✔️ 잔차는 정규성을 따른다고 볼 수 있음 (귀무가설 채택)

# %%
import matplotlib.pyplot as plt

plt.hist(residuals, bins=20, edgecolor='black')
plt.title('Histogram of Residuals')
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.show()
